# %% [markdown]
# # Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from wordcloud import WordCloud

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x) 
pd.set_option('display.max_rows',200)

# %%
videos_stats = pd.read_csv('videos_stats.csv')
videos_stats.head(80)
# Out:
#                                                 Title     Video ID  \
# 0   Apple Pay Is Killing the Physical Wallet After...  wAZZ-UWGVHI
# 1                     The most EXPENSIVE thing I own.  b3x28s61q3c
# 2                  My New House Gaming Setup is SICK!  4mgePWWCAmA
# 3   Petrol Vs Liquid Nitrogen | Freezing Experimen...  kXiYSI7H2b0
# 4                      Best Back to School Tech 2022!  ErMwWXQxHp0
# 5   Brewmaster Answers Beer Questions From Twitter...  18fwz9Itbvo
# 6   Tech Monopolies: Last Week Tonight with John O...  jXf04bhcjbg
# 7        I bought the STRANGEST TECH on the Internet.  2TqOmtTAMRY
# 8   15 Emerging Technologies that Will Change the ...  wLlL46pYcg4
# 9   Toxicologist Answers More Poison Questions Fro...  R7qsau3X6Ks
# 10        Dope Tech: The Most Extreme Gaming Monitor!  MEiq0oCUb_8
# 11                      Cool Tech Under $50 - August!  pT_9hntWj34
# 12       Cool Back to School Tech 2022 🔥 (Under $100)  cj4lxmHQV0o
# 13  Best Tech/EDC Gifts Under $50 for Father&#39;s...  d-BdIo8_wpA
# 14                     My Massive Tech Unboxing 47.0!  eFhhW6fsAbQ
# 15   Why Millennials Are Leaving Six-Figure Tech Jobs  N88OE2ZCHBM
# 16  10 Coolest Gadgets and Inventions That Will Bl...  PKATJiyz0iI
# 17            17 Coolest Gadgets You Can Actually Buy  qiMnSaZWf3M
# 18     Almost EVERYONE is Wasting Money on Dash Cams.  4AnyhHl3_tE
# 19           I bought the THINNEST Tech in the world.  nmY2kgWYwyQ
# 20  iPhone 14 Lineup is NOT what you Expected.. (p...  HMqyLcNmsec
# 21  Doctor Answers Gut Questions From Twitter | Te...  Q2ysbTVlPdk
# 22                        Cool Tech Under $50 - July!  zI8KQq5zmyM
# 23  Wolfgang Puck Answers Restaurant Questions Fro...  iEAlq1GPgnc
# 24  Battle Of The Tech - Super Bike Vs World Super...  IHnhSxizVOA
# 25     OnePlus 10R vs 10T | Unboxing &amp; Comparison  Ql1-RZ2FUrc
# 26  Tech Hiring Slowdown: What’s Different This Ti...  Fpof56HU6SY
# 27   10 New Tech Gadgets 2022 | You Can Buy Right Now  bbbQ_X45FaA
# 28  Taste Expert Answers Questions From Twitter | ...  MtMkU-1p7-0
# 29  Audiologist Answers Hearing Questions From Twi...  QYlXL_8ei6g
# 30  James Dyson Answers Design Questions From Twit...  zFCFe38EIfE
# 31                     My Massive Tech Unboxing 46.0!  LOrkbagIpiY
# 32                       Cool Tech Under $50 - April!  UK5OHUmIgcc
# 33  15 Emerging Technologies That Will Change Our ...  My2Tr3k1liw
# 34  Veterinarian Answers Pet Questions From Twitte...  IUwqf08-FKU
# 35  What Is The Best Position For Descending? | GC...  U48UrDpXGog
# 36                            My Everyday Tech: 2022!       #NAME?
# 37  INVENTIONS OF THE FUTURE THAT WILL SOON BE AVA...  _f8Gb-vojoU
# 38  Twitter Whistleblower Accuses Company of Priva...  MAeXrShneoQ
# 39  I Did a Terrible Job of This - Intel $5,000 Ex...  AREK4H8k7Ng
# 40                        Cool Tech Under $50 - June!  B0HI0RTZdJw
# 41       18 DEADLY Tech Fails that need to be BANNED.  Wuq7lS9rljw
# 42            I bought the BIGGEST Tech in the world.  VuG4BcghOSg
# 43  Neil Gaiman Answers Mythology Questions From T...  o-jUQhCeazQ
# 44  Sushi Chef Answers Sushi Questions From Twitte...       #NAME?
# 45  Futurum Research&#39;s Daniel Newman breaks do...       #NAME?
# 46                     My Favorite Tech of the Month!  UxjgqBamqDU
# 47  Paleontologist Answers Dinosaur Questions From...  YvZPU-KBCiQ
# 48  How Biden&#39;s student loan forgiveness progr...       #NAME?
# 49  Primary results in New York and Florida hold n...  4RkfqEWK2FI
# 50  Ex-CIA director predicts what&#39;s next in Ru...  GK8CFuXExLw
# 51  President Zelenskyy promises victory over Russ...  95MMQzBkE30
# 52  6 months later, what&#39;s next in the Ukraine...  nv7owOSprnI
# 53  More than 700 pages of classified documents fo...  rqbFOOt1q9M
# 54    Nadler Celebrates Win In New York House Primary  _XFJpfSFcpU
# 55  Biden Announces Plan For Federal Student Loan ...  fNHmQdrlIZE
# 56          Morning News NOW Full Broadcast - Aug. 23  zvS8Fmxv1_U
# 57  Biden plans to forgive $300 billion in student...  OTFKyW-vc_Y
# 58  ABC News Live: Trump files motion to bar revie...  IH3DYzS4MdI
# 59  More than 100 classified Trump docs recovered ...  q7sXUpqA_X4
# 60  National Shutdown | Workers hit the streets ov...  NS-9bd2hOOQ
# 61                       JORNAL DA MANHÃ - 24/08/2022  0IH09JBETbI
# 62  Trump legal team trying to stop Department of ...  lX3EBSNjPII
# 63  Netanyahu: This will make the Middle East a nu...  Tey5qEth4oA
# 64              Nightly News Full Broadcast - Aug. 19  L5p4Nov0KkU
# 65  Americans Are Angry And Worried About U.S. Fut...  MSTmUJU48g4
# 66  Breaking News: Jharkhand के CM Hemant Soren के...  Sdm1WsGGU0w
# 67  Zee Hindustan Live News: Attack On Nitish Kuma...  XHKojSQxTs0
# 68  【ライブ】最新ニュース：ウクライナ侵攻から半年/ロシア軍ミサイル攻撃の可能性/プーチン氏に近...  voU9-39bicg
# 69  අද දෙරණ 6.55 ප්‍රධාන පුවත් විකාශය -  2022.08.2...  88w5Q03Lcro
# 70  Najib ke penjara, Mahkamah Persekutuan kekal s...  B0ga0OUkb9c
# 71           Deadly car bomb detonates outside Moscow       #NAME?
# 72  Jail for Najib as Federal Court upholds ex-PM’...  o3TQPM5OkEU
# 73  Potential mass shooting foiled in Washington s...  lHDn25SLgdk
# 74  🔴 හිරු රාත්‍රී 6.55 ප්‍රධාන ප්‍රවෘත්ති ප්‍රකාශ...  kSKxCN8M-WE
# 75              Nightly News Full Broadcast - Aug. 18  fHCk3o_5l7o
# 76          Morning News NOW Full Broadcast - Aug. 19  8NL6YyEW2ww
# 77  Ukraine&#39;s Crimean fightback having &#39;ps...  uDSR4wV_zno
# 78    Dobol B TV Livestream: August 22, 2022 - Replay  f2TK2lpFFzs
# 79  🔴 Live at 8 ප්‍රධාන ප්‍රවෘත්ති විකාශය - 2022-0...  8Vqj8Ls29HI
#
#    Published At Keyword     Likes  Comments       Views
# 0    23/08/2022    tech   3407.00    672.00   135612.00
# 1    24/08/2022    tech  76779.00   4306.00  1758063.00
# 2    23/08/2022    tech  63825.00   3338.00  1564007.00
# 3    23/08/2022    tech  71566.00   1426.00   922918.00
# 4    08/08/2022    tech  96513.00   5155.00  1855644.00
# 5    05/11/2021    tech  33570.00   1643.00   943119.00
# 6    13/06/2022    tech 135047.00   9367.00  5937790.00
# 7    07/08/2022    tech 216935.00  12605.00  4782514.00
# 8    08/12/2021    tech  45565.00   2882.00  7001236.00
# 9    14/07/2022    tech  24252.00   1068.00   667767.00
# 10   15/08/2022    tech 118001.00   4123.00  2359142.00
# 11   06/08/2022    tech  20999.00   3091.00   413179.00
# 12   13/08/2022    tech  15322.00    547.00   389114.00
# 13   15/12/2021    tech  17866.00    157.00   444953.00
# 14   09/07/2022    tech  13217.00    442.00   371563.00
# 15   04/06/2021    tech  26890.00   4999.00  1633059.00
# 16   13/08/2021    tech   9562.00    199.00   760249.00
# 17   21/07/2022    tech  11743.00    143.00  1086568.00
# 18   14/08/2022    tech 146978.00  11105.00  3186890.00
# 19   25/03/2022    tech 363771.00  13609.00 11422924.00
# 20   24/08/2022    tech   2117.00    486.00    63650.00
# 21   12/05/2022    tech  42841.00   1357.00  1280387.00
# 22   02/07/2022    tech  23689.00   2842.00   530889.00
# 23   18/06/2021    tech  55231.00   2175.00  2122433.00
# 24   31/07/2022    tech   1289.00    183.00    35948.00
# 25   24/08/2022    tech    970.00    207.00    23175.00
# 26   10/08/2022    tech   1608.00    273.00    78520.00
# 27   27/05/2022    tech   1452.00     38.00    63599.00
# 28   03/06/2022    tech  35758.00   2056.00  1006704.00
# 29   19/08/2022    tech   8725.00    790.00   257848.00
# 30   30/11/2021    tech 110145.00   3289.00  2954979.00
# 31   28/05/2022    tech  12188.00    326.00   304037.00
# 32   02/04/2022    tech  59458.00   4159.00  1541386.00
# 33   14/05/2022    tech   3494.00    136.00   589007.00
# 34   05/05/2022    tech  36423.00   1902.00  1085076.00
# 35   24/08/2022    tech    941.00    221.00    25594.00
# 36   07/01/2022    tech 134194.00   6102.00  4098623.00
# 37   16/03/2022    tech  42075.00   1820.00  7188648.00
# 38   24/08/2022    tech    709.00    128.00    25745.00
# 39   23/07/2022    tech  78852.00   3926.00  1889567.00
# 40   04/06/2022    tech  32102.00   3243.00   786765.00
# 41   02/07/2022    tech 188623.00   7464.00  4195072.00
# 42   04/12/2021    tech 343227.00  20854.00  9618335.00
# 43   04/08/2022    tech  43960.00   1767.00   791624.00
# 44   26/05/2022    tech  77411.00   2098.00  2474364.00
# 45   24/08/2022    tech     24.00     45.00     3461.00
# 46   30/07/2022    tech   4492.00    169.00   274201.00
# 47   08/06/2022    tech  51846.00   2371.00  1156785.00
# 48   24/08/2022    news   1029.00   2347.00    97434.00
# 49   24/08/2022    news    534.00    538.00    57858.00
# 50   24/08/2022    news   8526.00   3934.00   544884.00
# 51   24/08/2022    news    588.00    887.00    69951.00
# 52   24/08/2022    news    137.00    222.00    18531.00
# 53   24/08/2022    news    848.00   1384.00    86855.00
# 54   24/08/2022    news    827.00   1653.00   131012.00
# 55   24/08/2022    news   1200.00   2841.00    54596.00
# 56   23/08/2022    news   1167.00    180.00   235019.00
# 57   24/08/2022    news   1573.00   2670.00    60528.00
# 58   23/08/2022    news   1145.00    793.00   106127.00
# 59   23/08/2022    news    474.00   1553.00    75301.00
# 60   24/08/2022    news     82.00     26.00    17145.00
# 61   24/08/2022    news  23828.00     47.00   500097.00
# 62   23/08/2022    news    775.00   1517.00   127082.00
# 63   24/08/2022    news   8484.00   2192.00   237313.00
# 64   20/08/2022    news   7946.00   1559.00   905023.00
# 65   21/08/2022    news    510.00    560.00    34715.00
# 66   24/08/2022    news    129.00      7.00    10642.00
# 67   24/08/2022    news   1288.00      3.00   172513.00
# 68   24/08/2022    news    257.00      1.00    62189.00
# 69   24/08/2022    news    612.00     18.00    60835.00
# 70   23/08/2022    news   2385.00   1349.00   288722.00
# 71   22/08/2022    news   6379.00   4853.00   808787.00
# 72   23/08/2022    news   1009.00    451.00   127803.00
# 73   22/08/2022    news   5630.00   1848.00   533947.00
# 74   24/08/2022    news    686.00     18.00    56683.00
# 75   19/08/2022    news   7277.00   1294.00   796750.00
# 76   19/08/2022    news    695.00    121.00   159877.00
# 77   20/08/2022    news  15854.00   5373.00  1465011.00
# 78   22/08/2022    news   1030.00     10.00   187892.00
# 79   24/08/2022    news    198.00     12.00    17763.00

# %%
comments = pd.read_csv('comments.csv')
# preview comments comment
# get the first comment
comment_text = comments['Comment'][0]
comment_text
# Out:
# "Let's not forget that Apple Pay in 2014 required a brand new iPhone in order to use it.  A significant portion of Apple's user base wasn't able to use it even if they wanted to.  As each successive iPhone incorporated the technology and older iPhones were replaced the number of people who could use the technology increased."

# %% [markdown]
# # Cleaning the data

# %% [markdown]
# looking for cells with invalid values

# %%
videos_stats.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1881 entries, 0 to 1880
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Title         1881 non-null   object
#  1   Video ID      1881 non-null   object
#  2   Published At  1881 non-null   object
#  3   Keyword       1881 non-null   object
#  4   Likes         1879 non-null   float64
#  5   Comments      1879 non-null   float64
#  6   Views         1879 non-null   float64
# dtypes: float64(3), object(4)
# memory usage: 103.0+ KB

# %%
videos_stats.isna().sum()
# Out:
# Title           0
# Video ID        0
# Published At    0
# Keyword         0
# Likes           2
# Comments        2
# Views           2
# dtype: int64

# %%
videos_stats = videos_stats.dropna()

# %% [markdown]
# Checking if there is invalid values for the likes and the comments

# %%
videos_stats[(videos_stats['Likes']<=0) | ( videos_stats['Comments']<=0) ]
# Out:
#                                                   Title     Video ID  \
# 243   How To Build A Business That Works | Brian Tra...  MN7yfV4UuCI
# 266   ตลาดถุงมือยางทรุด! ฉุดราคาร่วงลงทุนหด | BUSINE...  cG37cEi1nPc
# 583                         DON&#39;T GOOGLE THIS STUFF  NAV2laKrDv4
# 1016  15 Kilo Zayıf Gösteren Kız Makyajı |Arkadaşlar...       #NAME?
# 1393  Mathematics and Chemistry : MathChemistry.com ...  V_vguZj_7FE
# 1677  FULL Marvel Studios Panel from Hall H | San Di...  rf-NqJQJHBU
# 1701  SURVIVOR 🦀🦂 Best Action Movies 2022 🦀🦂 Latest ...  __7MkaWFObQ
# 1709  BEST Auditions Of Songs From Movies | Amazing ...  ZcBBGC8_mfU
# 1710  The Magnificent Seven - Full Movie In English ...  1MZY_0tYmrs
# 1711  TOP SECRET MISSION ⭐🌟 Best Action Movies 2022 ...  PIFa7wJ9c0c
# 1714  Vikram Vedha Movie Teaser Review | KRK | #krkr...  2FYvHn12pOQ
#
#      Published At        Keyword    Likes  Comments      Views
# 243    09/02/2021       business    -1.00   1144.00  676300.00
# 266    23/08/2022       business    -1.00     13.00   12332.00
# 583    28/08/2017         google    -1.00  18676.00 6515548.00
# 1016   23/08/2022        mukbang    -1.00    335.00   27451.00
# 1393   15/04/2013  mathchemistry     0.00      1.00      25.00
# 1677   24/07/2022         marvel    -1.00    821.00  553892.00
# 1701   20/08/2022         movies   105.00     -1.00   28219.00
# 1709   25/07/2022         movies 20138.00     -1.00 5351960.00
# 1710   29/12/2021         movies    -1.00    180.00 2389222.00
# 1711   18/07/2022         movies   643.00      0.00   24012.00
# 1714   24/08/2022         movies    -1.00    105.00 1541874.00

# %% [markdown]
# There is 11 entries with wrong values in either likes and comments
# we can fix it by first checking if those videos are actuall existing videos by searching or validating using the video Id which is the link of the video but, they are few so it's unecceary, we will drop them

# %%
videos_stats = videos_stats[(videos_stats['Likes']>0) & ( videos_stats['Comments']>0) ]

# %% [markdown]
# Checking the datatypes

# %%
videos_stats.dtypes
# Out:
# Title            object
# Video ID         object
# Published At     object
# Keyword          object
# Likes           float64
# Comments        float64
# Views           float64
# dtype: object

# %%
videos_stats['Published At'] = pd.to_datetime(videos_stats ['Published At'], format='%d/%m/%Y', errors='coerce')

# %% [markdown]
# changing the data type of  views, likes and comments to int

# %%
# transforming columns from float to int64
videos_stats['Views'] = videos_stats['Views'].astype('int64')
videos_stats['Likes'] = videos_stats['Likes'].astype('int64')
videos_stats['Comments'] = videos_stats['Comments'].astype('int64')
videos_stats['Keyword'] = videos_stats['Keyword'].astype(str)

# %%
videos_stats.describe()
# Out:
#                         Published At       Likes  Comments         Views
# count                           1868     1868.00   1868.00       1868.00
# mean   2021-06-04 20:23:22.997858560   171051.27   7898.25   11672135.57
# min              2007-07-16 00:00:00        1.00      1.00         63.00
# 25%              2021-02-20 06:00:00     2705.25    201.00      85156.25
# 50%              2022-06-13 12:00:00    15011.00    820.00     591947.00
# 75%              2022-08-23 00:00:00    61091.75   3411.50    2814055.25
# max              2022-08-24 00:00:00 16445558.00 732818.00 4034122271.00
# std                              NaN   798466.37  37986.47  108761106.89

# %%
# Check for empty or whitespace-only titles
empty_titles = videos_stats['Title'].str.strip() == ''

# Check for non-string titles
non_string_titles = videos_stats['Title'].apply(lambda x: not isinstance(x, str))

# %%
videos_stats[empty_titles ]
# Out:
# Empty DataFrame
# Columns: [Title, Video ID, Published At, Keyword, Likes, Comments, Views]
# Index: []

# %%
videos_stats[non_string_titles]
# Out:
# Empty DataFrame
# Columns: [Title, Video ID, Published At, Keyword, Likes, Comments, Views]
# Index: []

# %% [markdown]
# Also we will find in some titles text like "& #39;" which  HTML entity representing the apostrophe character

# %% [markdown]
# The ID length should be 11 characters,so if we checked for enteries that doesn't met this critaria, we will find some with missing video Id, but they might be valid videos but they are little so removing them will make the dataset cleaner

# %%
invalid_length_video_ids = videos_stats['Video ID'].apply(lambda x: len(x) != 11)
videos_stats[invalid_length_video_ids]
# Drop rows with invalid video IDs
videos_stats = videos_stats[~invalid_length_video_ids]

# %%
# showing duplicates before droping them
videos_stats[videos_stats.duplicated(subset='Video ID', keep=False)]
# Out:
#                                                   Title     Video ID  \
# 2                    My New House Gaming Setup is SICK!  4mgePWWCAmA
# 88                   My New House Gaming Setup is SICK!  4mgePWWCAmA
# 91                          I OPENED MY OWN ARCADE SHOP  WBK2_lD7KGA
# 129   ASMR Gaming 😴 Fortnite 1 Kill = 1 Trigger Rela...  mqc6QqoGNWI
# 225             How to Solve a Rubik&#39;s Cube | WIRED  R-R0KrXvWbc
# 319   20 Minecraft Block Facts You Maybe Didn&#39;t ...  LeC5yJq4tsI
# 423             How to Solve a Rubik&#39;s Cube | WIRED  R-R0KrXvWbc
# 472            The History Of Chess: A Reflection Of Us  kkOweffr3II
# 682            The History Of Chess: A Reflection Of Us  kkOweffr3II
# 848   ASMR Gaming 😴 Fortnite 1 Kill = 1 Trigger Rela...  mqc6QqoGNWI
# 891   Lofi For Reading 📚 Lofi Hip Hop | Study Music ...  ZgeorpjGJC0
# 916       BLACKPINK - ‘Pink Venom’ DANCE PRACTICE VIDEO  RFMi3v0TXP8
# 1041      BLACKPINK - ‘Pink Venom’ DANCE PRACTICE VIDEO  RFMi3v0TXP8
# 1077  Lofi For Reading 📚 Lofi Hip Hop | Study Music ...  ZgeorpjGJC0
# 1220  20 Minecraft Block Facts You Maybe Didn&#39;t ...  LeC5yJq4tsI
# 1229                        I OPENED MY OWN ARCADE SHOP  WBK2_lD7KGA
# 1501  Computer Scientist Explains Machine Learning i...  5q87K1WaoFI
# 1554  🚨 DÉPÊCHEZ-VOUS 🚨 Ces PROMOS disparaissent bie...  96mrgd8-3yE
# 1595  🚨 DÉPÊCHEZ-VOUS 🚨 Ces PROMOS disparaissent bie...  96mrgd8-3yE
# 1762    Python Machine Learning Tutorial (Data Science)  7eh4d6sabA0
# 1832  Computer Scientist Explains Machine Learning i...  5q87K1WaoFI
# 1835    Python Machine Learning Tutorial (Data Science)  7eh4d6sabA0
#
#      Published At           Keyword    Likes  Comments     Views
# 2      2022-08-23              tech    63825      3338   1564007
# 88     2022-08-23            gaming    63825      3338   1564007
# 91     2022-08-24            gaming   298406     15609   3773387
# 129    2022-08-24            gaming      563        85     14537
# 225    2019-09-05            how-to   339758     32718  29905105
# 319    2022-08-21          tutorial    57526      1115   1204024
# 423    2019-09-05             cubes   339759     32717  29905105
# 472    2022-08-21             chess     2546       173     51885
# 682    2022-08-21           history     2546       173     51885
# 848    2022-08-24              asmr      563        86     14537
# 891    2022-08-24             music      329        29     14336
# 916    2022-08-24             music  3001232    110160  23836066
# 1041   2022-08-24          reaction  3001265    110162  23836066
# 1077   2022-08-24              lofi      329        29     14341
# 1220   2022-08-21         minecraft    57527      1115   1204024
# 1229   2022-08-24         minecraft   298445     15610   3773387
# 1501   2021-08-18  computer science    42940      1735   1407319
# 1554   2022-08-24          nintendo      406        57     13184
# 1595   2022-08-24              xbox      406        57     13184
# 1762   2020-09-17      data science     7555       442    295344
# 1832   2021-08-18  machine learning    15137       181    906372
# 1835   2020-09-17  machine learning     1237        16     32605

# %%
# removing duplicates with the same video id and keeping the first one from videos_stats
videos_stats = videos_stats.drop_duplicates(subset='Video ID', keep='first')
# show if there are any duplicates
videos_stats[videos_stats.duplicated(subset='Video ID', keep=False)]
# Out:
# Empty DataFrame
# Columns: [Title, Video ID, Published At, Keyword, Likes, Comments, Views]
# Index: []

# %%
# data cleaning for the comments dataset
comments.info()
comments.isna().sum()
# drop rows with missing values
comments = comments.dropna()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18409 entries, 0 to 18408
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Video ID   18409 non-null  object
#  1   Comment    18408 non-null  object
#  2   Likes      18409 non-null  int64
#  3   Sentiment  18409 non-null  int64
# dtypes: int64(2), object(2)
# memory usage: 575.4+ KB

# %%
# Check for empty or whitespace-only comments
empty_comments = comments['Comment'].str.strip() == ''
print(comments[empty_comments])
# Out:
# Empty DataFrame
# Columns: [Video ID, Comment, Likes, Sentiment]
# Index: []

# %% [markdown]
# ## Feature engineering

# %%
videos_to_change_indexs = [557,652,227,1129,653]
videos_stats.loc[videos_to_change_indexs, 'Keyword'] = 'music'
# print a list of all keywords
videos_stats['Keyword'].unique()
#creating categories for the keywords
categories = {
    "Technology": ['tech', 'apple', 'google'],
    "News": ['news', 'cnn'],
    "Gaming": ['gaming', 'minecraft', 'nintendo', 'xbox'],
    "Sports": ['sports', 'chess'],
    "How-To/Tutorials": ['how-to', 'tutorial'],
    "Business/Finance": ['business', 'finance', 'crypto','interview'],
    "History/Literature": ['history', 'literature'],
    "Entertainment": ['bed', 'trolling', 'asmr', 'music', 'food', 'mukbang', 'reaction', 'lofi', 'animals', 'mrbeast','marvel' ,'movies','cubes'],
    "Education": ['education', 'sat', 'mathchemistry', 'biology', 'physics'],
    "Computer Science": ['computer science','game development','data science','machine learning']
}

# Function to map keywords to categories
def map_keyword_to_category(keyword):
    for category, keywords in categories.items():
        if keyword in keywords:
            return category
    return 'Uncategorized'

# Create the new 'category' column
videos_stats['Category'] = videos_stats['Keyword'].apply(map_keyword_to_category)

# %%
# saving the video stats to  a new csv file called cleaned_video_stats.csv
videos_stats.to_csv('cleaned_video_stats.csv', index=False)

# %% [markdown]
# # Exploratory Data Analysis (EDA)

# %% [markdown]
# ## Summary statistics

# %%
videos_stats.describe()
# Out:
#                         Published At       Likes  Comments         Views
# count                           1828     1828.00   1828.00       1828.00
# mean   2021-05-30 18:46:28.621444096   171151.87   7918.01   11734196.38
# min              2007-07-16 00:00:00        1.00      1.00         63.00
# 25%              2021-02-05 18:00:00     2718.25    207.00      85271.25
# 50%              2022-06-12 12:00:00    15011.00    821.00     591947.00
# 75%              2022-08-22 00:00:00    60863.50   3387.50    2814055.25
# max              2022-08-24 00:00:00 16445558.00 732818.00 4034122271.00
# std                              NaN   803956.78  38299.12  109880552.59

# %% [markdown]
# It looks like there is high difference between the median and the mean, and very high variation indicating that they are
# outliers, so before we take insgihgts right away let's look at those trendy videos are they actual videos? and how can we understand the centeral tendcy of likes, comments and views if those videos skew the data

# %%
# Here we are going to use the standard values of the interquartile range to detect outliers
# and we are going to look at it to see if they are actuall values
q1 = videos_stats['Views'].quantile(0.25)
q3 = videos_stats['Views'].quantile(0.75)
iqr = q3 - q1
lower_bound = q1 - 1.5*iqr
upper_bound = q3 + 1.5*iqr
outliers =(videos_stats['Views'] < lower_bound) | (videos_stats['Views'] > upper_bound)
trendy = videos_stats[outliers]
trendy.sort_values('Views', ascending=False)
# Out:
#                                                   Title     Video ID  \
# 557   El Chombo - Dame Tu Cosita feat. Cutty Ranks (...  FzG4uDgje3M
# 1121           Martin Garrix - Animals (Official Video)  gCYcHz2k5x0
# 922   The Weeknd - Save Your Tears (Official Music V...  XXYlFuWEuKI
# 1118          Maroon 5 - Animals (Official Music Video)  qpgTC9MDx1o
# 752   Powfu - death bed (coffee for your head) (Offi...  jJPMnTXl63E
# ...                                                 ...          ...
# 1425                              Girls Aloud - Biology  bBPtP4t2J1k
# 322   Tutorial 😍 do u want to see the result? XO TEA...  ud9TRfHA1EM
# 1495           3 years of Computer Science in 8 minutes  ReVeUvwTGdU
# 8     15 Emerging Technologies that Will Change the ...  wLlL46pYcg4
# 1325                 100 Million Subscriber Livestream!  er5LLR2oCmg
#
#      Published At           Keyword     Likes  Comments       Views  \
# 557    2018-04-05             music  16445558    732818  4034122271
# 1121   2013-06-17           animals  11025176    335455  1582262997
# 922    2021-01-05             music   6823113    270948   915457091
# 1118   2014-09-29           animals   5743875    178361   826423766
# 752    2020-04-01               bed   7786057    195769   524709805
# ...           ...               ...       ...       ...         ...
# 1425   2009-06-26           biology     18353      2560     7073338
# 322    2022-07-25          tutorial    375997      2031     7009241
# 1495   2018-07-24  computer science    186881      8575     7004107
# 8      2021-12-08              tech     45565      2882     7001236
# 1325   2022-07-28           mrbeast    492024     41183     6968660
#
#               Category
# 557      Entertainment
# 1121     Entertainment
# 922      Entertainment
# 1118     Entertainment
# 752      Entertainment
# ...                ...
# 1425         Education
# 322   How-To/Tutorials
# 1495  Computer Science
# 8           Technology
# 1325     Entertainment
#
# [281 rows x 8 columns]

# %% [markdown]
# looks like we got a big ratio of our dataset that include vey popular videos, so we shoudn't remove them

# %% [markdown]
# Now let's look at summary statistics again but this time including looking at the average and variation from non-trendy video metrics to understand the baseline performance without the influence of viral content.

# %%
# create a new dataset with the outliers removed and call it a smart name like videos_stats_no_trendy
videos_stats_no_trendy = videos_stats[~outliers]

# %%
videos_stats_no_trendy.describe()
# Out:
#                         Published At     Likes  Comments      Views
# count                           1547   1547.00   1547.00    1547.00
# mean   2021-09-28 08:28:14.117647104  27930.69   1767.85 1008287.39
# min              2009-08-20 00:00:00      1.00      1.00      63.00
# 25%              2021-09-27 12:00:00   2115.00    169.00   63772.50
# 50%              2022-07-26 00:00:00   9093.00    571.00  338844.00
# 75%              2022-08-23 00:00:00  31687.50   1706.00 1323957.50
# max              2022-08-24 00:00:00 634419.00  48673.00 6897438.00
# std                              NaN  49834.30   3480.28 1462579.31

# %%
videos_stats.describe()
# Out:
#                         Published At       Likes  Comments         Views
# count                           1828     1828.00   1828.00       1828.00
# mean   2021-05-30 18:46:28.621444096   171151.87   7918.01   11734196.38
# min              2007-07-16 00:00:00        1.00      1.00         63.00
# 25%              2021-02-05 18:00:00     2718.25    207.00      85271.25
# 50%              2022-06-12 12:00:00    15011.00    821.00     591947.00
# 75%              2022-08-22 00:00:00    60863.50   3387.50    2814055.25
# max              2022-08-24 00:00:00 16445558.00 732818.00 4034122271.00
# std                              NaN   803956.78  38299.12  109880552.59

# %% [markdown]
# By comparing the basline stats without the insanly popular videos and the whole dataset
# we can see that the there is no big difference in median but mean and variation is a big difference so
# Likes:
# median:15000
# mean:28000
# std:50000
#
# Comments:
# median:800
# mean:7918
# std:38299
#
# Views:
# median:591947
# mean:1008287
# std:1462579

# %%
# lets study the correlation between the views, likes and comments with a heatmap and ensuring that the likes and comments are shown int the heatmap
correlation = videos_stats[['Views', 'Likes', 'Comments']].corr('spearman')
correlation
# Out:
#           Views  Likes  Comments
# Views      1.00   0.95      0.84
# Likes      0.95   1.00      0.87
# Comments   0.84   0.87      1.00

# %%
# Create summary statistics for categories of videos
category_stats_non_trendy = videos_stats_no_trendy.groupby('Category').agg({'Views': 'mean', 'Likes': 'mean', 'Comments': 'mean'})
#change the column names to views mean, likes mean and comments mean
category_stats_non_trendy.columns = ['Views_mean', 'Likes_mean', 'Comments_mean']
category_stats_all = videos_stats.groupby('Category').agg({'Views': ['count', 'sum', 'median'], 'Likes': ['sum', 'median'], 'Comments': ['sum', 'median']})
# merege the two datasets
category_stats_all.columns = ['_'.join(col).strip() for col in category_stats_all.columns.values]
# change views count to number of videos
category_stats_all = category_stats_all.rename(columns={'Views_count': 'Number of Videos'})

category_stats = pd.merge(category_stats_all, category_stats_non_trendy, left_index=True, right_index=True)
category_stats.sort_values('Views_sum', ascending=False)
# Out:
#                     Number of Videos    Views_sum  Views_median  Likes_sum  \
# Category
# Entertainment                    592  17682706815    1220518.00  238840943
# Technology                       129   1024688768     589007.00   12060394
# How-To/Tutorials                  98    712897277    2252959.00   16013155
# Education                        184    544910647     929426.00   12483038
# Sports                            93    377546018     901368.00    5261051
# Business/Finance                 182    333350063      96965.00    6337957
# History/Literature                91    289787379     649114.00    8337173
# Gaming                           182    269437697     134500.00    7722928
# Computer Science                 190    178328327     325771.00    5257086
# News                              87     36457993     288312.00     551890
#
#                     Likes_median  Comments_sum  Comments_median  Views_mean  \
# Category
# Entertainment           24995.50       9947070           998.00  1181113.32
# Technology              17866.00        768554          1146.00  1102158.96
# How-To/Tutorials        62959.00        730439          2019.50  1746781.48
# Education               24545.50        702406          1313.00  1286191.16
# Sports                  11053.00        213683           640.00  1250450.71
# Business/Finance         3402.50        402351           465.00   780422.68
# History/Literature      11841.00        589287           726.00  1070946.88
# Gaming                   5480.50        498879           468.50   613739.58
# Computer Science        11445.50        203769           460.50   759113.42
# News                     4836.00        417691          3004.00   419057.39
#
#                     Likes_mean  Comments_mean
# Category
# Entertainment         33325.19        1476.34
# Technology            34438.43        2549.83
# How-To/Tutorials      55232.90        2075.17
# Education             34554.68        1901.31
# Sports                26304.83        1442.51
# Business/Finance      20644.32        1662.24
# History/Literature    21067.69        1502.43
# Gaming                21579.86        1579.23
# Computer Science      22199.50         859.89
# News                   6343.56        4801.05

# %%
# bar graph for the mean views for each category and the number of videos in each category
# bar graph for the number of videos in each category
# show beside each other

plt.figure(figsize=(10, 6))
sns.barplot(x=category_stats.index, y=category_stats['Views_mean'])
plt.xticks(rotation=90)
plt.xlabel('Category')
plt.ylabel('Mean Views')
plt.title('Mean Views by Category')


plt.figure(figsize=(10, 6))
sns.barplot(x=category_stats.index, y=category_stats['Number of Videos'])
plt.xticks(rotation=90)
plt.xlabel('Category')
plt.ylabel('Number of Videos')
plt.title('Number of Videos by Category')

# show both graphs beside each other
plt.show()

# %%
# bar graph for the mean views for each category and the number of videos in each categor

# %%
# show top 20 videos with the most views and likes sorted for entertainment category
entertainment = videos_stats[videos_stats['Category'] == 'Entertainment']
entertainment = entertainment.sort_values('Views', ascending=False)
entertainment[['Title', 'Views', 'Likes', 'Comments']].head(20)
# Out:
#                                                   Title       Views     Likes  \
# 557   El Chombo - Dame Tu Cosita feat. Cutty Ranks (...  4034122271  16445558
# 1121           Martin Garrix - Animals (Official Video)  1582262997  11025176
# 922   The Weeknd - Save Your Tears (Official Music V...   915457091   6823113
# 1118          Maroon 5 - Animals (Official Music Video)   826423766   5743875
# 752   Powfu - death bed (coffee for your head) (Offi...   524709805   7786057
# 652            One Direction - History (Official Video)   434352213   5400589
# 1145        Glass Animals - Heat Waves (Official Video)   378164492   6177588
# 757       Young Money - Bed Rock (Official Music Video)   321977550   1430457
# 775                       Rihanna - California King Bed   308501014   1171433
# 764      Bon Jovi - Bed Of Roses (Official Music Video)   302125099   1072689
# 1286                  $456,000 Squid Game In Real Life!   285526909  14259033
# 901   NLE Choppa - Walk Em Down feat. Roddy Ricch [O...   250793774   2286473
# 227        Tiësto - The Business (Official Music Video)   208293677   1706185
# 1129                   Maroon 5 - Animals (Lyric Video)   193685278   1019385
# 1292                      I Spent 50 Hours Buried Alive   191988678   6055504
# 1308                 Last To Leave Circle Wins $500,000   180766617   4437532
# 459                        Ice Cube - It Was A Good Day   168546247   2307773
# 1149  Damn Nature You Scary | Funny Scary Animal Enc...   161103805    639942
# 1298      Going Through The Same Drive Thru 1,000 Times   160818375   3557658
# 1320                       I Ate A $70,000 Golden Pizza   156000008   3206546
#
#       Comments
# 557     732818
# 1121    335455
# 922     270948
# 1118    178361
# 752     195769
# 652     434688
# 1145    125791
# 757      84188
# 775      61344
# 764      37571
# 1286    611757
# 901      86935
# 227      25334
# 1129     24603
# 1292    239172
# 1308    109214
# 459      71897
# 1149     23316
# 1298    127113
# 1320    108235

# %%
# plot a pie chart for the number of total views for each keyword for the entertainment category
entertainment_keyword_views = entertainment.groupby('Keyword')['Views'].sum()
entertainment_keyword_views = entertainment_keyword_views.sort_values(ascending=False)
plt.figure(figsize=(10, 10))
plt.pie(entertainment_keyword_views, labels=entertainment_keyword_views.index, autopct='%1.1f%%')
plt.title('Total Views by Keyword for Entertainment Category')
plt.show()

# %%
# show the top 20 videos with the most views and likes sorted for the Technology category
technology = videos_stats[videos_stats['Category'] == 'Technology']
technology = technology.sort_values('Views', ascending=False)
technology[['Title', 'Views', 'Likes', 'Comments']].head(20)
# Out:
#                                                  Title      Views    Likes  \
# 527  PIKOTARO - PPAP (Pen Pineapple Apple Pen) (Lon...  425478119  4144389
# 591                       Google — Year In Search 2021  239207161   169669
# 555                  If Google Was A Guy (Full Series)   34484565  1046404
# 590  Top New Comedy Video Amazing Funny Video 2021 ...   32300300   135952
# 560      360° Google Dinosaur - T-REX in VR [4K] Video   26160434   193174
# 594             How Google Search Works (in 5 minutes)   20026987   124675
# 577  LIFE-SAVING GADGETS and EMERGENCY HACKS YOU SH...   15836037    88325
# 554                       The Weirdest GOOGLE Searches   14296001   472660
# 559                                 Fun Google Secrets   14269018   234520
# 19            I bought the THINNEST Tech in the world.   11422924   363771
# 571                  28 STRANGE Sights on Google Earth    9914057    51098
# 565                              www.google.com search    9826182     8383
# 42             I bought the BIGGEST Tech in the world.    9618335   343227
# 573                Weird Things Spotted On Google Maps    9277945   237800
# 561                          Never Google this word...    8496353   261832
# 536               iOS 16 Hands-On: Top 5 New Features!    7544821   274209
# 37   INVENTIONS OF THE FUTURE THAT WILL SOON BE AVA...    7188648    42075
# 8    15 Emerging Technologies that Will Change the ...    7001236    45565
# 569  A Day In The Life Of Sundar Pichai (Google&#39...    6123730   107571
# 6    Tech Monopolies: Last Week Tonight with John O...    5937790   135047
#
#      Comments
# 527    294428
# 591      8630
# 555     37539
# 590      2131
# 560      4232
# 594      5828
# 577      1460
# 554     37391
# 559      9846
# 19      13609
# 571      5463
# 565       773
# 42      20854
# 573     20092
# 561      8894
# 536      9651
# 37       1820
# 8        2882
# 569      3380
# 6        9367

# %%
# plot a pie chart for the number of total views for each keyword for the technology category
technology_keyword_views = technology.groupby('Keyword')['Views'].sum()
technology_keyword_views = technology_keyword_views.sort_values(ascending=False)
plt.figure(figsize=(10, 10))
plt.pie(technology_keyword_views, labels=technology_keyword_views.index, autopct='%1.1f%%')
plt.title('Total Views by Keyword for Technology Category')
plt.show()

# %%
# analyse videos with keyword 'data science' and 'machine learning'
data_science = videos_stats[(videos_stats['Keyword'] == 'data science' )|( videos_stats['Keyword'] == 'machine learning')]
data_science[['Title','Likes','Comments','Views']].sort_values('Views', ascending=False).head(20)
# Out:
#                                                   Title   Likes  Comments  \
# 1838              Machine Learning Course for Beginners  300789      6254
# 1851  2020 Machine Learning Roadmap (95% valid for 2...  176978      7152
# 1858  How I Learnt Machine Learning In 6 Steps (3 mo...  463331     21849
# 1863   Machine Learning Fundamentals: Bias and Variance  109335      2712
# 1731  Data Science In 5 Minutes | Data Science For B...   55282       576
# 1831  Machine Learning Basics | What Is Machine Lear...   43189      1155
# 1773   Work Week In My Life | Data Scientist at Spotify   55097      1543
# 1834                          What is Machine Learning?   38776       566
# 1746                     Is Data Science Dying in 2022?   56267      1146
# 1732                              What is Data Science?   51915       876
# 1847  Intro to Machine Learning (ML Zero to Hero - P...   34464       822
# 1760  How to choose between software engineering and...   36835      1265
# 1833  Machine Learning Full Course - Learn Machine L...   36835      1265
# 1850                The Mathematics of Machine Learning   27736       692
# 1859           Deep Learning Crash Course for Beginners   18847        76
# 1855  Machine Learning with Python | Machine Learnin...   26619      1070
# 1837                  Machine Learning vs Deep Learning   18982       402
# 1751                      How to get a data science job   30536       742
# 1853          MarI/O - Machine Learning for Video Games   29980       897
# 1769  What is Data Science? | Complete RoadMap | Sim...   44518      1273
#
#          Views
# 1838  11814893
# 1851  10817160
# 1858   7497071
# 1863   5028230
# 1731   2586478
# 1831   2317183
# 1773   2287752
# 1834   2278698
# 1746   2214491
# 1732   2197690
# 1847   1651599
# 1760   1456270
# 1833   1456270
# 1850   1432027
# 1859   1414209
# 1855   1378069
# 1837   1339489
# 1751   1332052
# 1853   1167616
# 1769   1058423

# %% [markdown]
# Most preforming videos in the data science field are mostly about

# %%
# Grouping data by industry (keyword) and calculating basic engagement metrics
industry_engagement_metrics_for_all_videos = videos_stats.groupby('Keyword').agg({
    'Views': [ 'median','min','max','sum','mean'],
    'Likes': ['median','min','max','sum','mean'],
    'Comments': ['median','min','max','sum','mean']
}).reset_index()

industry_engagement_metrics_for_all_videos .columns = ['_'.join(col).strip() for col in industry_engagement_metrics_for_all_videos .columns.values]
industry_engagement_metrics_for_all_videos .rename(columns={'Keyword_': 'Industry'}, inplace=True)

industry_engagement_metrics_without_trendy = videos_stats_no_trendy.groupby('Keyword').agg({
    'Views': [ 'mean'],
    'Likes': ['mean'],
    'Comments': ['mean']
}).reset_index()

industry_engagement_metrics_without_trendy.columns = ['_'.join(col).strip() for col in industry_engagement_metrics_without_trendy.columns.values]
industry_engagement_metrics_without_trendy.rename(columns={'Keyword_': 'Industry'}, inplace=True)

industry_engagement_metrics = pd.merge(industry_engagement_metrics_for_all_videos, industry_engagement_metrics_without_trendy, on='Industry', suffixes=('_all_videos', '_without_trendy'))

industry_engagement_metrics[['Industry','Views_median','Views_max','Views_mean_without_trendy']].sort_values('Views_mean_without_trendy', ascending=False)
# Out:
#             Industry  Views_median   Views_max  Views_mean_without_trendy
# 28           mrbeast   65074742.50   285526909                 3282953.83
# 10             cubes    4795109.00   168546247                 2570294.59
# 14              food    2456819.00    48018833                 2150667.82
# 0            animals    4466776.00  1582262997                 2052390.86
# 39          tutorial    2817913.50    68512549                 1875008.41
# 3                bed    9359070.50   524709805                 1856188.24
# 4            biology    1743151.00    23925458                 1825077.97
# 17            google    2328295.00   239207161                 1789878.80
# 25     mathchemistry    1806999.00    18496859                 1757909.75
# 27            movies    1293718.00    65067408                 1695848.97
# 36            sports    1890798.50    57369066                 1635266.06
# 19            how-to    2023665.50    52061447                 1622218.17
# 20         interview    1187250.00    22529756                 1598385.95
# 33           physics    1299208.50    42252029                 1457446.62
# 12         education     575543.00    17103736                 1413975.81
# 18           history     962507.00   147339243                 1310061.38
# 37              tech     943119.00    11422924                 1226710.78
# 24            marvel    1461872.00    54583132                 1132921.86
# 8   computer science     405950.50     7004107                 1093514.31
# 5           business     668071.50    54244089                  967758.00
# 6              chess     180651.00    13844095                  946178.12
# 22              lofi     497458.00    84747957                  888439.88
# 32          nintendo     208877.00    31667627                  882321.33
# 21        literature     557735.00     4231789                  863021.24
# 38          trolling     611040.00    14286302                  841508.47
# 29           mukbang     906361.00    86169225                  833548.66
# 23  machine learning     512182.00    11814893                  742716.44
# 15  game development     318051.00     6478696                  732258.02
# 30             music     250073.50  4034122271                  687572.57
# 40              xbox      83683.50    22439610                  609500.55
# 26         minecraft     187668.00    23169378                  577870.00
# 7                cnn     474328.50     1889320                  554240.38
# 35               sat     240450.00    18116954                  542855.94
# 11      data science     266203.00     2586478                  493255.14
# 13           finance      29751.00     9450554                  463793.68
# 1              apple     159616.00   425478119                  458703.47
# 2               asmr      78423.00    33779197                  376467.11
# 16            gaming      98595.00     7132206                  349088.28
# 31              news     106690.00     1465011                  236377.68
# 9             crypto      23410.50    11805668                  171933.53
# 34          reaction      40053.00     1765945                  127055.79

# %%
# bar chart for the mean views for non trendy videos  while sorting the industries by the mean views for non trendy videos
# color in #03EC61
plt.figure(figsize=(20, 10))
sns.barplot(data=industry_engagement_metrics.sort_values(by='Views_mean_without_trendy', ascending=False), x='Views_mean_without_trendy', y='Industry', color='#03EC61')
plt.xlabel('Mean views')
plt.ylabel('Industry')
# font of x and y labels
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.title('Mean views for witout-trendy videos by industry')
plt.show()

# %%
# number of videos over the time in years visualized in a bar chart
videos_stats['Published At'].dt.year.value_counts().sort_index().plot(kind='bar')
plt.xlabel('Year')
plt.ylabel('Number of videos')
plt.title('Number of videos over the years')
plt.show()

# %%
# number of videos over the time in months for 2022 visualized in a bar chart
videos_stats[videos_stats['Published At'].dt.year == 2022]['Published At'].dt.month.value_counts().sort_index().plot(kind='bar')
plt.xlabel('Month')
plt.ylabel('Number of videos')
plt.title('Number of videos over the months in 2022')
plt.show()

# %% [markdown]
# Looks like 750 videos out of 1800 of the dataset came from augest 2022 which is the last month collected in the dataset

# %%
industry_engagement_metrics[['Industry','Views_mean_without_trendy','Views_mean_all_videos']].sort_values(by=['Views_mean_without_trendy','Views_mean_all_videos'],ascending=False)
# Out:
#             Industry  Views_mean_without_trendy  Views_mean_all_videos
# 28           mrbeast                 3282953.83            66764003.98
# 10             cubes                 2570294.59            14735344.12
# 14              food                 2150667.82             5252406.25
# 0            animals                 2052390.86            94598820.33
# 39          tutorial                 1875008.41             6761032.02
# 3                bed                 1856188.24            53893228.61
# 4            biology                 1825077.97             4121605.83
# 17            google                 1789878.80            11614081.05
# 25     mathchemistry                 1757909.75             3565846.71
# 27            movies                 1695848.97             5278660.05
# 36            sports                 1635266.06             6571761.73
# 19            how-to                 1622218.17             7809284.92
# 20         interview                 1598385.95             3013969.39
# 33           physics                 1457446.62             3692387.28
# 12         education                 1413975.81             2684432.83
# 18           history                 1310061.38             5557520.04
# 37              tech                 1226710.78             1900584.11
# 24            marvel                 1132921.86             6737756.86
# 8   computer science                 1093514.31             1222005.46
# 5           business                  967758.00             3144555.41
# 6              chess                  946178.12             1380032.33
# 22              lofi                  888439.88             4185880.00
# 32          nintendo                  882321.33             1695053.79
# 21        literature                  863021.24              863021.24
# 38          trolling                  841508.47             1420141.02
# 29           mukbang                  833548.66            10993303.16
# 23  machine learning                  742716.44             1349259.37
# 15  game development                  732258.02              732258.02
# 30             music                  687572.57           125673724.86
# 40              xbox                  609500.55             1739205.85
# 26         minecraft                  577870.00             1820034.87
# 7                cnn                  554240.38              554240.38
# 35               sat                  542855.94             1065868.71
# 11      data science                  493255.14              493255.14
# 13           finance                  463793.68              694223.44
# 1              apple                  458703.47            10746930.45
# 2               asmr                  376467.11             1292095.89
# 16            gaming                  349088.28              518666.22
# 31              news                  236377.68              236377.68
# 9             crypto                  171933.53              404608.22
# 34          reaction                  127055.79              127055.79

# %% [markdown]
# Let's look at the very popular videos
# Since outliers are actual trendy videos, removing them is not an option because they drive important insights

# %%
# Generate a word cloud for the 'Keyword' column
keyword_counts = " ".join(keyword for keyword in videos_stats['Keyword'])
wordcloud = WordCloud(width = 800, height = 400, background_color ='white',collocations=False).generate(keyword_counts)
# Display the word cloud
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# show top 100 most viewed videos
top_100_videos = videos_stats.sort_values(by='Views', ascending=False).head(10)
top_100_videos
# Out:
#                                                   Title     Video ID  \
# 557   El Chombo - Dame Tu Cosita feat. Cutty Ranks (...  FzG4uDgje3M
# 1121           Martin Garrix - Animals (Official Video)  gCYcHz2k5x0
# 922   The Weeknd - Save Your Tears (Official Music V...  XXYlFuWEuKI
# 1118          Maroon 5 - Animals (Official Music Video)  qpgTC9MDx1o
# 752   Powfu - death bed (coffee for your head) (Offi...  jJPMnTXl63E
# 652            One Direction - History (Official Video)  yjmp8CoZBIo
# 527   PIKOTARO - PPAP (Pen Pineapple Apple Pen) (Lon...  Ct6BUPvE2sM
# 1145        Glass Animals - Heat Waves (Official Video)  mRD0-GxqHVo
# 757       Young Money - Bed Rock (Official Music Video)  Ha80ZaecGkQ
# 775                       Rihanna - California King Bed  nhBorPm6JjQ
#
#      Published At  Keyword     Likes  Comments       Views       Category
# 557    2018-04-05    music  16445558    732818  4034122271  Entertainment
# 1121   2013-06-17  animals  11025176    335455  1582262997  Entertainment
# 922    2021-01-05    music   6823113    270948   915457091  Entertainment
# 1118   2014-09-29  animals   5743875    178361   826423766  Entertainment
# 752    2020-04-01      bed   7786057    195769   524709805  Entertainment
# 652    2016-01-26    music   5400589    434688   434352213  Entertainment
# 527    2016-11-02    apple   4144389    294428   425478119     Technology
# 1145   2020-06-29  animals   6177588    125791   378164492  Entertainment
# 757    2009-12-16      bed   1430457     84188   321977550  Entertainment
# 775    2011-05-07      bed   1171433     61344   308501014  Entertainment

# %%
videos_to_change_indexs = [557,652,227,1129,653]
videos_stats.loc[videos_to_change_indexs, 'Keyword'] = 'music'
# print a list of all keywords
videos_stats['Keyword'].unique()
#creating categories for the keywords
categories = {
    "Technology": ['tech', 'apple', 'google'],
    "News": ['news', 'cnn'],
    "Gaming": ['gaming', 'minecraft', 'nintendo', 'xbox'],
    "Sports": ['sports', 'chess'],
    "How-To/Tutorials": ['how-to', 'tutorial'],
    "Business/Finance": ['business', 'finance', 'crypto','interview'],
    "History/Literature": ['history', 'literature'],
    "Entertainment": ['bed', 'trolling', 'asmr', 'music', 'food', 'mukbang', 'reaction', 'lofi', 'animals', 'mrbeast','marvel' ,'movies','cubes'],
    "Education": ['education', 'sat', 'mathchemistry', 'biology', 'physics'],
    "Computer Science": ['computer science','game development','data science','machine learning']
}

# Function to map keywords to categories
def map_keyword_to_category(keyword):
    for category, keywords in categories.items():
        if keyword in keywords:
            return category
    return 'Uncategorized'

# Create the new 'category' column
videos_stats['Category'] = videos_stats['Keyword'].apply(map_keyword_to_category)

# %%
# Create a pie chart showing the the views for each category
plt.figure(figsize=(10, 10))
videos_stats['Category'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.ylabel('')
plt.title('Distribution of videos by category')
plt.show()

# %%
# show the top 10 vieos in education category
top_10_education_videos = videos_stats[videos_stats['Category'] == 'Education'].sort_values(by='Views', ascending=False).head(10)
top_10_education_videos
# Out:
#                                                   Title     Video ID  \
# 1475          When a physics teacher knows his stuff !!  77ZF50ve6rs
# 1396    Biology: Cell Structure I Nucleus Medical Media  URUJD5NEXC8
# 1461  Michio Kaku: The Universe in a Nutshell (Full ...  0NbBjNiw4tk
# 1386     SCIENCE WARS - Acapella Parody | SCIENCE SONGS  LTXTeAt2mpg
# 1278              SAT Math: The Ultimate Guessing Trick  Z1-8o3bH674
# 1433                    Biology: Digestive System Video  bo2Ape8JHqA
# 1169          RSA ANIMATE: Changing Education Paradigms  zDZFcDGpL4U
# 1464  8 Year Old LOST His GIRLFRIEND To A Rich Kid, ...  c0Ir6O1JB-I
# 1410        1. Introduction to Human Behavioral Biology  NNnIGh9g6fA
# 1476                     Amazing Physics Toys/Gadgets 1  Y5dylh2aOiw
#
#      Published At        Keyword    Likes  Comments     Views   Category
# 1475   2016-03-04        physics  1194852     16417  42252029  Education
# 1396   2015-03-18        biology   396477     10721  23925458  Education
# 1461   2012-08-15        physics   296448     29736  19097087  Education
# 1386   2015-12-04  mathchemistry   542855     43802  18496859  Education
# 1278   2011-10-07            sat   712273     32736  18116954  Education
# 1433   2009-02-16        biology   132214      5981  17716356  Education
# 1169   2010-10-14      education   130817      6868  17103736  Education
# 1464   2019-11-19        physics   673896     41869  14835017  Education
# 1410   2011-02-01        biology   310947     15981  14800155  Education
# 1476   2022-02-26        physics   188472      5901  13829574  Education

# %%
# show the order of the most popular keywords within the education category based on views
education_keywords_by_views = videos_stats[videos_stats['Category'] == 'Education'].groupby('Keyword').agg({'Views': 'sum'}).sort_values(by='Views', ascending=False)
education_keywords_by_views
# Out:
#                    Views
# Keyword
# biology        193715474
# physics        184619364
# education       64426388
# sat             52227567
# mathchemistry   49921854

# %% [markdown]
# # Sentiment analysis

# %%
import re
import nltk
import emoji 
from nltk.sentiment.vader import SentimentIntensityAnalyzer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# %%
nltk.download('stopwords')
stop_words = set(stopwords.words())

def convert_emojis_to_text(text):
    # remove _ from emojis demojize
    return emoji.demojize(text, delimiters=(" ", " "))

# Function to remove stopwords
def remove_stopwords(text):
    words = text.split()
    filtered_words = [word for word in words if word.lower() not in stop_words]
    return ' '.join(filtered_words)

# Combine both preprocessing functions
def preprocess_text(text):
    text = convert_emojis_to_text(text)
    text = remove_stopwords(text)
    return text

comments['Comment'] = comments['Comment'].apply(preprocess_text)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\USCS\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Initialize VADER
nltk.download('vader_lexicon')
sid = SentimentIntensityAnalyzer()

# Perform sentiment analysis
comments['Sentiment_score'] = comments['Comment'].apply(lambda x: sid.polarity_scores(x))
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\USCS\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
def classify_sentiment(compound_score):
    if compound_score['compound'] <= -0.05:
        return 0  # Negative
    elif compound_score['compound'] < 0.05:
        return 1  # Neutral
    else:
        return 2  # Positive

# Apply the classification to your dataframe
comments['sentiment_class'] = comments['Sentiment_score'].apply(classify_sentiment)

# Display the first few rows to verify
comments
# Out:
#           Video ID                                            Comment  Likes  \
# 0      wAZZ-UWGVHI  forget Apple Pay 2014 required brand iPhone or...     95
# 1      wAZZ-UWGVHI  NZ 50% retailers don’t contactless credit card...     19
# 2      wAZZ-UWGVHI  forever acknowledge channel lessons ideas expl...    161
# 3      wAZZ-UWGVHI  place doesn’t Apple Pay (doesn’t happen often)...      8
# 4      wAZZ-UWGVHI  Apple Pay convenient, secure, easy use. Korean...     34
# ...            ...                                                ...    ...
# 18404  cyLWtMSry58  point engineering toolboxes. that’s lot burnou...      0
# 18405  cyLWtMSry58  I’ve started exploring field. reminder early j...     20
# 18406  cyLWtMSry58  Excelente video pregunta filosófica profunda. ...      1
# 18407  cyLWtMSry58  Hey Daniel, discovered channel couple days ago...     35
# 18408  cyLWtMSry58  great. Focus key. playful approach speed thing...      0
#
#        Sentiment                                    Sentiment_score  \
# 0              1  {'neg': 0.108, 'neu': 0.654, 'pos': 0.239, 'co...
# 1              0  {'neg': 0.071, 'neu': 0.66, 'pos': 0.269, 'com...
# 2              2  {'neg': 0.0, 'neu': 0.503, 'pos': 0.497, 'comp...
# 3              0  {'neg': 0.326, 'neu': 0.674, 'pos': 0.0, 'comp...
# 4              2  {'neg': 0.081, 'neu': 0.462, 'pos': 0.457, 'co...
# ...          ...                                                ...
# 18404          2  {'neg': 0.0, 'neu': 0.924, 'pos': 0.076, 'comp...
# 18405          2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18406          1  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18407          2  {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound...
# 18408          2  {'neg': 0.0, 'neu': 0.678, 'pos': 0.322, 'comp...
#
#        sentiment_class
# 0                    2
# 1                    2
# 2                    2
# 3                    0
# 4                    2
# ...                ...
# 18404                2
# 18405                1
# 18406                1
# 18407                1
# 18408                2
#
# [18408 rows x 6 columns]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score


# change Sentiment to existing_sentiment_score
comments.rename(columns={'Sentiment': 'existing_sentiment_class'}, inplace=True)
# Calculate the confusion matrix
conf_matrix = confusion_matrix(comments['existing_sentiment_class'], comments['sentiment_class'])

# Calculate accuracy, precision, recall, and F1-score
accuracy = accuracy_score(comments['existing_sentiment_class'], comments['sentiment_class'])
precision = precision_score(comments['existing_sentiment_class'], comments['sentiment_class'], average='weighted')
recall = recall_score(comments['existing_sentiment_class'], comments['sentiment_class'], average='weighted')
f1 = f1_score(comments['existing_sentiment_class'], comments['sentiment_class'], average='weighted')

# Display the results
print("Confusion Matrix:\n", conf_matrix)
print("Accuracay:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
#       4 # change Sentiment to existing_sentiment_score
#       5 comments.rename(columns={'Sentiment': 'existing_sentiment_class'}, inplace=True)
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# create bar plot for the sentiment classes
plt.figure(figsize=(10, 6))
sns.countplot(data=comments, x='sentiment_class')
plt.xlabel('Sentiment Class')
plt.ylabel('Number of Comments')
plt.title('Sentiment Class Distribution')
plt.show()

# %%
# create bar plot for the sentiment classes
plt.figure(figsize=(10, 6))
sns.countplot(data=comments, x='existing_sentiment_class')
plt.xlabel('Sentiment Class')
plt.ylabel('Number of Comments')
plt.title('Existing Sentiment Class Distribution')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[57], line 3
#       1 # create bar plot for the sentiment classes
#       2 plt.figure(figsize=(10, 6))
# ----> 3 sns.countplot(data=comments, x='existing_sentiment_class')
#       4 plt.xlabel('Sentiment Class')
#       5 plt.ylabel('Number of Comments')
#
# File d:\DataScienceProjects\datacampcomp\myenv\lib\site-packages\seaborn\categorical.py:2631, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, hue_norm, stat, width, dodge, gap, log_scale, native_scale, formatter, legend, ax, **kwargs)
#    2628 elif x is not None and y is not None:
#    2629     raise TypeError("Cannot pass values for both `x` and `y`.")
# -> 2631 p = _CategoricalAggPlotter(
#    2632     data=data,
#    2633     variables=dict(x=x, y=y, hue=hue),
#    2634     order=order,
#    2635     orient=orient,
#    2636     color=color,
#    2637     legend=legend,
#    2638 )
#    2640 if ax is None:
#    2641     ax = plt.gca()
#
# File d:\DataScienceProjects\datacampcomp\myenv\lib\site-packages\seaborn\categorical.py:67, in _CategoricalPlotter.__init__(self, data, variables, order, orient, require_numeric, color, legend)
#      56 def __init__(
#      57     self,
#      58     data=None,
#    (...)
#      64     legend="auto",
#      65 ):
# ---> 67     super().__init__(data=data, variables=variables)
#      69     # This method takes care of some bookkeeping that is necessary because the
#      70     # original categorical plots (prior to the 2021 refactor) had some rules that
#      71     # don't fit exactly into VectorPlotter logic. It may be wise to have a second
#    (...)
#      76     # default VectorPlotter rules. If we do decide to make orient part of the
#      77     # _base variable assignment, we'll want to figure out how to express that.
#      78     if self.input_format == "wide" and orient in ["h", "y"]:
#
# File d:\DataScienceProjects\datacampcomp\myenv\lib\site-packages\seaborn\_base.py:634, in VectorPlotter.__init__(self, data, variables)
#     629 # var_ordered is relevant only for categorical axis variables, and may
#     630 # be better handled by an internal axis information object that tracks
#     631 # such information and is set up by the scale_* methods. The analogous
#     632 # information for numeric axes would be information about log scales.
#     633 self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 634 self.assign_variables(data, variables)
#     636 # TODO Lots of tests assume that these are called to initialize the
#     637 # mappings to default values on class initialization. I'd prefer to
#     638 # move away from that and only have a mapping when explicitly called.
#     639 for var in ["hue", "size", "style"]:
#
# File d:\DataScienceProjects\datacampcomp\myenv\lib\site-packages\seaborn\_base.py:679, in VectorPlotter.assign_variables(self, data, variables)
#     674 else:
#     675     # When dealing with long-form input, use the newer PlotData
#     676     # object (internal but introduced for the objects interface)
#     677     # to centralize / standardize data consumption logic.
#     678     self.input_format = "long"
# --> 679     plot_data = PlotData(data, variables)
#     680     frame = plot_data.frame
#     681     names = plot_data.names
#
# File d:\DataScienceProjects\datacampcomp\myenv\lib\site-packages\seaborn\_core\data.py:58, in PlotData.__init__(self, data, variables)
#      51 def __init__(
#      52     self,
#      53     data: DataSource,
#      54     variables: dict[str, VariableSpec],
#      55 ):
#      57     data = handle_data_source(data)
# ---> 58     frame, names, ids = self._assign_variables(data, variables)
#      60     self.frame = frame
#      61     self.names = names
#
# File d:\DataScienceProjects\datacampcomp\myenv\lib\site-packages\seaborn\_core\data.py:232, in PlotData._assign_variables(self, data, variables)
#     230     else:
#     231         err += "An entry with this name does not appear in `data`."
# --> 232     raise ValueError(err)
#     234 else:
#     235
#     236     # Otherwise, assume the value somehow represents data
#     237
#     238     # Ignore empty data structures
#     239     if isinstance(val, Sized) and len(val) == 0:
#
# ValueError: Could not interpret value `existing_sentiment_class` for `x`. An entry with this name does not appear in `data`.

# %%
# Value counts for the sentiment classes and the existing sentiment classes
comments['sentiment_class'].value_counts()
# Out:
# sentiment_class
# 2    11345
# 1     4296
# 0     2767
# Name: count, dtype: int64

# %%
comments['existing_sentiment_class'].value_counts()
# Out:
# 2    11432
# 1     4638
# 0     2338
# Name: existing_sentiment_class, dtype: int64

# %%
comments.dtypes
# Out:
# Video ID                    object
# Comment                     object
# Likes                        int64
# existing_sentiment_class     int64
# Sentiment_score             object
# sentiment_class              int64
# dtype: object

# %%
# show the rows where existing sentiment is not equatl sentiment class
# expand Comment column width
pd.set_option('display.max_colwidth', None)

comments[comments['existing_sentiment_class'] != comments['sentiment_class']]
# Out:
#           Video ID  \
# 0      wAZZ-UWGVHI
# 1      wAZZ-UWGVHI
# 5      wAZZ-UWGVHI
# 7      wAZZ-UWGVHI
# 20     4mgePWWCAmA
# ...            ...
# 18394  f_uwKZIAeM0
# 18399  cyLWtMSry58
# 18403  cyLWtMSry58
# 18405  cyLWtMSry58
# 18407  cyLWtMSry58
#
#                                                                                                                                                                                                                                                                                                  Comment  \
# 0                                                                                                   forget Apple Pay 2014 required brand iPhone order it. significant portion Apple's user base wanted to. successive iPhone incorporated technology older iPhones replaced number technology increased.
# 1                                                                                                                                                                                             NZ 50% retailers don’t contactless credit card machines pay-wave support Apple Pay. don’t high fees these.
# 5                                                                                                                                                                                                                 We’ve hounding bank adopt Apple pay. understand don’t extra fees, easy quick checkout.
# 7                                                                                                                                                                                                                                                                   now, Apple Pay physical credit card.
# 20                                                                                                                                                                 Linus!!! turn key lights 180 bounce walls. You’ll softer glow shadow lighting. It’s simple fix. I’m lines idea beam lights directly 😅
# ...                                                                                                                                                                                                                                                                                                  ...
# 18394                                                                                                                                                                                                                                                                     explanation machine learning🔥🔥
# 18399                                       currently enrolled MSc Machine learning masters UK, learning theory putting practice assignments. problem both. Stop telling can't.. put time effort learning mindset method, learn eat drink time. smart it. Stop putting limiting thoughts yourself. hard.
# 18403  Back learning code didn’t it. asked friend books read etc. stop sentence “you don’t research functions data structures notes textbooks, possible” reasonated possible, problem video states “learn doing”, friend work I’m projects solve replicate implement learned way. sitting reading books.
# 18405                                                                                                                                                                                                                                         I’ve started exploring field. reminder early journey. lot!
# 18407                                                                                                                                                                                                                                 Hey Daniel, discovered channel couple days ago learning lots. you!
#
#        Likes  existing_sentiment_class  \
# 0         95                         1
# 1         19                         0
# 5          8                         1
# 7          7                         1
# 20       456                         2
# ...      ...                       ...
# 18394      0                         2
# 18399    575                         2
# 18403     33                         1
# 18405     20                         2
# 18407     35                         2
#
#                                                        Sentiment_score  \
# 0       {'neg': 0.108, 'neu': 0.654, 'pos': 0.239, 'compound': 0.4588}
# 1        {'neg': 0.071, 'neu': 0.66, 'pos': 0.269, 'compound': 0.5994}
# 5       {'neg': 0.087, 'neu': 0.625, 'pos': 0.287, 'compound': 0.4939}
# 7          {'neg': 0.175, 'neu': 0.5, 'pos': 0.325, 'compound': 0.296}
# 20               {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# ...                                                                ...
# 18394            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 18399  {'neg': 0.206, 'neu': 0.728, 'pos': 0.066, 'compound': -0.5859}
# 18403   {'neg': 0.101, 'neu': 0.702, 'pos': 0.196, 'compound': 0.5574}
# 18405            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
# 18407            {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}
#
#        sentiment_class
# 0                    2
# 1                    2
# 5                    2
# 7                    2
# 20                   1
# ...                ...
# 18394                1
# 18399                0
# 18403                2
# 18405                1
# 18407                1
#
# [5861 rows x 6 columns]

# %%
# show comment with emojis
comments[comments['Comment'].str.contains('😂')]
# Out:
# Empty DataFrame
# Columns: [Video ID, Comment, Likes, Sentiment, Sentiment_score, sentiment_class]
# Index: []

# %%
# testing VADER for a comment with emojis
text =convert_emojis_to_text('😁')
print(text)
sid.polarity_scores(text)
# Out:
#  beaming_face_with_smiling_eyes
# {'neg': 0.0, 'neu': 1.0, 'pos': 0.0, 'compound': 0.0}

# %%
sid.polarity_scores('😁')
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 0.0, 'compound': 0.0}
